# %% [markdown]
# # 01 Data Understanding
#
# Validate the raw Home Credit files and generate the schema summary report. This notebook does not modify raw data and does not train models.

# %%
from pathlib import Path
import sys

project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent
sys.path.insert(0, str(project_root))
project_root

# %%
from src.data.load_data import (
    REPORT_PATH,
    load_base_table,
    print_console_summary,
    summarize_dtypes,
    summarize_missing_values,
    summarize_target,
    validate_required_files,
)

validate_required_files()
base_df = load_base_table()
target_summary = summarize_target(base_df)
missing_summary = summarize_missing_values(base_df)
dtype_summary = summarize_dtypes(base_df)
print_console_summary(base_df, target_summary, missing_summary, dtype_summary, REPORT_PATH)

# %%
target_summary

# %%
missing_summary.head(20)
