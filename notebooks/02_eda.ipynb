# %% [markdown]
# # 02 Exploratory Data Analysis
#
# Run the portfolio EDA for `application_train.csv`, save business-readable findings, and generate plots under `reports/figures/`. This notebook does not modify raw data and does not train models.

# %%
from pathlib import Path
import sys

project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent
sys.path.insert(0, str(project_root))
project_root

# %%
from src.data.eda_utils import EDA_REPORT_PATH, run_eda

artifacts = run_eda()
EDA_REPORT_PATH

# %%
artifacts["target_summary"]

# %%
artifacts["segment_rates"].head(20)

# %%
for idx, finding in enumerate(artifacts["findings"], start=1):
    print(f"{idx}. {finding}")
